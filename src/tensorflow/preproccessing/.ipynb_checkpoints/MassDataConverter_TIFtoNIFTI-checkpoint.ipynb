# %%
import os
from skimage import io
import numpy

# %%
image_directory="/home/gautham/bkly/LatticeLightSheet/TrialData/"
save_directory="/home/gautham/bkly/LatticeLightSheet/ConvertedData/"

# %%
import nibabel as nib
import numpy as np

for filename in os.listdir(image_directory):
    if filename.endswith(".tif"): 
        #Convert TIF to numpy array
        image_path = os.path.join(image_directory, filename)
        im = io.imread(image_path)
        #Convert numpy array to NIFTI
        nifti_file = nib.Nifti1Image(im, affine=np.eye(4))
        print(type(nifti_file))
        nib.save(nifti_file, save_directory+filename[:-4]+'.nii.gz')
        continue
    else:
        print(filename+" not converted")
        continue
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# <class 'nibabel.nifti1.Nifti1Image'>
# ...

# %%
#If a specific file needs to be viewed within jupyter, use nilearn

#from nilearn import plotting
#plotting.plot_img(nifti_file, display_mode='z',cut_coords=100, title="display_mode='z', cut_coords=100")


#For manual viewing, upload the NIFTI file to https://brainbrowser.cbrain.mcgill.ca/volume-viewer
#Use Saggital mode
